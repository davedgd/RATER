# %%
# %cd ~/RATER-C/results
# Out:
# /home/daved/RATER-C/results

# %%
from glob import glob

import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix
from netcal.metrics import ECE

# %%
files = glob('*_preds.csv')
model_names = [file.split('_preds.csv')[0] for file in files]

# %%
res = []

for model_name in model_names:

    test = pd.read_csv(model_name + '_preds.csv')
    test.head(3)
    
    y_true = test['target']
    probs = test['prob']
    preds = np.where(probs >= 0.5, 1, 0)
    
    tn, fp, fn, tp = confusion_matrix(y_true, preds).ravel()
    auc = np.round(roc_auc_score(y_true, probs), 3)
    f1 = np.round(f1_score(y_true, preds), 3)
    macro_f1 = np.round(f1_score(y_true, preds, average = 'macro'), 3)
    
    n_bins = 7
    ece = np.round(ECE(bins = n_bins).measure(np.array(probs), np.array(y_true)), 3)
    
    metrics = {
        'model': model_name.replace('_', '/'),
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'tp': tp,
        'f1': f1,
        'auc': auc,
        'macro_f1': macro_f1,
        'ece': ece
    }

    out = pd.DataFrame.from_dict(metrics, orient = 'index').transpose()
    res.append(out)
    
pd.concat(res).reset_index(drop = True).sort_values(['auc', 'macro_f1'], ascending = False)
# Out:
#                              model     tn    fp    fn    tp     f1    auc  \
# 10      microsoft/deberta-v3-large  27557  1632  1540  2575  0.619  0.911
# 3        microsoft/deberta-v3-base  28061  1128  1964  2151  0.582  0.904
# 8          microsoft/deberta-large  28207   982  2188  1927  0.549  0.893
# 12          microsoft/deberta-base  27595  1594  1830  2285  0.572  0.887
# 6          xlnet/xlnet-large-cased  27453  1736  1818  2297  0.564  0.882
# 13      microsoft/deberta-v3-small  27834  1355  1976  2139  0.562  0.877
# 5   google-bert/bert-large-uncased  28022  1167  2129  1986  0.547  0.877
# 0          FacebookAI/roberta-base  27036  2153  1645  2470  0.565  0.873
# 2      microsoft/deberta-v3-xsmall  27596  1593  1960  2155  0.548  0.872
# 1            albert/albert-base-v2  28354   835  2476  1639  0.497  0.871
# 11          albert/albert-large-v2  28442   747  2549  1566  0.487  0.866
# 9           xlnet/xlnet-base-cased  27963  1226  2326  1789  0.502  0.861
# 4    google-bert/bert-base-uncased  27953  1236  2208  1907  0.525   0.86
# 14        FacebookAI/roberta-large  28577   612  2691  1424  0.463  0.859
# 7        google/mobilebert-uncased  27788  1401  2375  1740   0.48  0.841
#
#    macro_f1    ece
# 10    0.782  0.076
# 3     0.765  0.018
# 8     0.748  0.079
# 12    0.757  0.033
# 6     0.752  0.077
# 13    0.753  0.031
# 5     0.745  0.027
# 0      0.75  0.083
# 2     0.744  0.036
# 1     0.721   0.01
# 11    0.716  0.077
# 9     0.721  0.029
# 4     0.734  0.035
# 14    0.704  0.069
# 7     0.708  0.039
